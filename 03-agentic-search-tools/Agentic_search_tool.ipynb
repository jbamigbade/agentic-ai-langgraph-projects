# %%
from getpass import getpass
import os

os.environ["TAVILY_API_KEY"] = getpass("Enter Tavily API key: ")
# Out:
# Enter Tavily API key:  ········

# %%
print(os.environ["TAVILY_API_KEY"][:5])
# Out:
# tvly-

# %%
# libraries
from dotenv import load_dotenv
import os
from tavily import TavilyClient

# load environment variables from .env file
_ = load_dotenv()

# connect
client = TavilyClient(api_key=os.environ.get("TAVILY_API_KEY"))

# %%
# run search
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)

# print the answer
result["answer"]
# Out:
# 'The new Blackwell GPU by Nvidia features 208 billion transistors and is made with a custom TSMC 4NP process. It succeeds the Hopper and Ada Lovelace architectures. Blackwell Ultra chips are set to ship later in 2026.'

# %%
# choose location (try to change to your own city!)

city = "San Francisco"

query = f"""
    what is the current weather in {city}?
    Should I travel there today?
    "weather.com"
"""

# %%
# !pip install duckduckgo-search
# Out:
# Requirement already satisfied: duckduckgo-search in D:\Miniforge326.3.2-2\Lib\site-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in D:\Miniforge326.3.2-2\Lib\site-packages (from duckduckgo-search) (8.4.0)
# Requirement already satisfied: primp>=0.15.0 in D:\Miniforge326.3.2-2\Lib\site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in D:\Miniforge326.3.2-2\Lib\site-packages (from duckduckgo-search) (6.1.1)
# Requirement already satisfied: colorama in D:\Miniforge326.3.2-2\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# WARNING: Ignoring invalid distribution ~penai (D:\Miniforge326.3.2-2\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (D:\Miniforge326.3.2-2\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (D:\Miniforge326.3.2-2\Lib\site-packages)

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re

ddg = DDGS()

def search(query, max_results=6):
    try:
        results = ddg.text(query, max_results=max_results)
        return [i["href"] for i in results]
    except Exception as e:
        print(f"returning previous results due to exception reaching ddg.")
        results = [ # cover case where DDG rate limits due to high deeplearning.ai volume
            "https://weather.com/weather/today/l/USCA0987:1:US",
            "https://weather.com/weather/hourbyhour/l/54f9d8baac32496f6b5497b4bf7a277c3e2e6cc5625de69680e6169e7e38e9a8",
        ]
        return results  


for i in search(query):
    print(i)
# Out:
# C:\Users\johnb\AppData\Local\Temp\ipykernel_19892\2852339428.py:6: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddg = DDGS()

# %%
def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."
    
    # fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."

    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# use DuckDuckGo to find websites and take the first result
results = search(query)

print(results)

if len(results) > 0:
    url = results[0]

    soup = scrape_weather_info(url)

    print(f"Website: {url}\n\n")
    print(str(soup.body)[:50000])

else:
    print("No search results found.")
# Out:
# []
# No search results found.

# %%
results = search(query)

print(results)

if len(results) > 0:
    url = results[0]

    soup = scrape_weather_info(url)

    print(f"Website: {url}\n\n")

else:
    print("No search results found.")
# Out:
# []
# No search results found.

# %%
url = "https://weather.com/weather/today/l/USCA0987:1:US"

soup = scrape_weather_info(url)

print(f"Website: {url}\n\n")
# Out:
# Website: https://weather.com/weather/today/l/USCA0987:1:US

# %%
# extract text
weather_data = []

for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove extra spaces
weather_data = re.sub(r'\s+', ' ', weather_data)

print(weather_data[:5000])
# Out:
# Home Home Forecast Forecast Radar Radar Video Video Explore Explore San Francisco Weather Downtown, San Francisco, California Today's Outlook Things to do around San Francisco Daily Forecast Trending Now Hurricanes, Tornadoes, Heat: The Main June Weather Changes 1:25 Adorable Baby Elephant Charges Safari Tourists 0:23 Waterspout Hits Florida Beach, Sends People Scampering 0:26 Europe Is Baking. Here's How To Cool Off Under A Blazing Heat Dome Hurricanes, Tornadoes, Heat: The Main June Weather Changes 1:25 Adorable Baby Elephant Charges Safari Tourists 0:23 Waterspout Hits Florida Beach, Sends People Scampering 0:26 Europe Is Baking. Here's How To Cool Off Under A Blazing Heat Dome Home & Garden Former Texas Coal Mine Is Now A Garden Feeding Thousands 0:56 How To Stop Leaking Money During A Drought 1:03 Your Drought To-Do List 0:37 Homeowner’s Guide To Termite Season 0:34 Former Texas Coal Mine Is Now A Garden Feeding Thousands 0:56 How To Stop Leaking Money During A Drought 1:03 Your Drought To-Do List 0:37 Homeowner’s Guide To Termite Season 0:34 Editor's Pick Tennessee High School Grads Brave Downpour For Diplomas Nothing could stop these Tennessee high school graduates – not even a torrential downpour that turned their ceremony into an unforgettable spectacle. Watch as Centennial High School seniors in Franklin refuse to abandon their milestone moment, clutching soggy diplomas while their families cheered them on. 0:23 The Weather Channel is the world's most accurate forecaster according to ForecastWatch, Global and Regional Weather Forecast Accuracy Overview , 2021-2024, commissioned by The Weather Company. Weather Channel. Privacy & Legal Terms of Use Privacy Policy Data Rights Privacy Settings Cookie Notice Data Vendors AdChoices Accessibility Statement Community Guidelines More Mission Newsletter Sign Up Feedback Careers News Room Advertise With Us TV Weather Data APIs Alexa Skill Weather Labs Atmosphere © The Weather Company, LLC 2026
